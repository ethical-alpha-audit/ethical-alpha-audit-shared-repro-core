# %% [markdown]
# > **Academic viewing:** In **Voila** or **Binder’s Voila URL** (`/voila/render/...`), input cells are not shown to readers—only narrative and live controls. In classic Jupyter, an implementation cell appears below; it calls shared helpers and does not reimplement engine logic.
#
#
# # Demo pipeline — interactive instrument (archival)
#
# **Execute:** `technical/03_demo_pipeline_execute.ipynb`.
#
# ## How to use
#
# **Restart & Run All**; move **Case index** among {0,1,2}.
#
# ## Interactive experiment surface

# %%
from archival_notebook_helpers import launch_03_demo_pipeline_interactive

launch_03_demo_pipeline_interactive()

# %% [markdown]
# ## Interpretation & integrity
#
# Full-mode **`evaluate_case`** per index; **no** `outputs/` writes here.
