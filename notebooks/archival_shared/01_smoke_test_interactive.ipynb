# %% [markdown]
# > **Academic viewing:** In **Voila** or **Binder’s Voila URL** (`/voila/render/...`), input cells are not shown to readers—only narrative and live controls. In classic Jupyter, an implementation cell appears below; it calls shared helpers and does not reimplement engine logic.
#
#
# # Shared-core smoke test — interactive instrument (archival)
#
# **Pair with:** `01_smoke_test.ipynb` (markdown-only narrative). **Canonical writes:** `technical/01_smoke_test_execute.ipynb`.
#
# ## Title & purpose
#
# Same as the story notebook: **auditable decision framework**, replay-mode smoke on bounded scenarios.
#
# ## What this demonstrates & why it matters
#
# Live **dropdown** across two **predefined** cases shows how **gate activation** and **replay** verdict fields move with features while **thresholds** stay in the engine module.
#
# ## How to use
#
# **Restart & Run All.** Adjust **Scenario**; read the panel. **No** edits to code or free numeric entry.
#
# ## Interactive experiment surface
#
# Run the cell below to mount controls (engine-backed).

# %% [markdown]
# ## Launch bounded controls

# %%
from archival_notebook_helpers import launch_01_smoke_interactive

launch_01_smoke_interactive()

# %% [markdown]
# ## Interpretation & integrity
#
# Outcomes come from **`evaluate_case(..., profile_name="moderate", mode=MODE_REPLAY)`**. **Disk artefacts** remain the responsibility of the **execute** notebook + harness. This instrument does **not** write under `outputs/`.
