# %% [markdown]
# > **Academic viewing:** In **Voila** or **Binder’s Voila URL** (`/voila/render/...`), input cells are not shown to readers—only narrative and live controls. In classic Jupyter, an implementation cell appears below; it calls shared helpers and does not reimplement engine logic.
#
#
# # Utilities validation — interactive instrument (archival)
#
# **Execute companion:** `technical/02_utilities_validation_execute.ipynb`.
#
# ## How to use
#
# **Restart & Run All**, then change **Feature preset**.
#
# ## Interactive experiment surface

# %%
from archival_notebook_helpers import launch_02_utilities_interactive

launch_02_utilities_interactive()

# %% [markdown]
# ## Interpretation & integrity
#
# Same engine calls as contract path; this notebook performs **no** writes under `outputs/tables/`.
