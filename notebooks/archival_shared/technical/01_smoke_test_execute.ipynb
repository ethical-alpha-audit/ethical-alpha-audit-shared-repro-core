# %% [markdown]
# # Technical — smoke test contract execution
#
# **Layer B.** Regenerates hash-locked `smoke_test` artefacts. Invoked by `python reproduce_all.py`. **Not** the primary reader surface.

# %%
import sys
from pathlib import Path

_here = Path.cwd().resolve()
_shared = _here.parent
if str(_shared) not in sys.path:
    sys.path.insert(0, str(_shared))

from archival_notebook_helpers import run_01_smoke_test_contract_only

run_01_smoke_test_contract_only()
# Out:
# Smoke test artifacts written.
