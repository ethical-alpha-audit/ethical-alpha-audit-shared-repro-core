# %% [markdown]
# # Technical — demo pipeline contract
#
# **Layer B.** Writes `outputs/figures/demo_pipeline_summary.txt`.

# %%
import sys
from pathlib import Path

_here = Path.cwd().resolve()
_shared = _here.parent
if str(_shared) not in sys.path:
    sys.path.insert(0, str(_shared))

from archival_notebook_helpers import run_03_demo_pipeline_contract_only

run_03_demo_pipeline_contract_only()
# Out:
# Demo pipeline summary written.
