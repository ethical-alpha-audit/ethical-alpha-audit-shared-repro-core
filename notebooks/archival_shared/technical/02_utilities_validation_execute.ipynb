# %% [markdown]
# # Technical — utilities validation contract
#
# **Layer B.** Writes `outputs/tables/utilities_validation.csv`.

# %%
import sys
from pathlib import Path

_here = Path.cwd().resolve()
_shared = _here.parent
if str(_shared) not in sys.path:
    sys.path.insert(0, str(_shared))

from archival_notebook_helpers import run_02_utilities_validation_contract_only

run_02_utilities_validation_contract_only()
# Out:
# Utilities validation CSV written.
