# %% [markdown]
# # 01_core_demo.ipynb\n\nDemonstrate shared core helpers.\n\nReplace this starter notebook with the live analysis for the manuscript.\n

# %%
from pathlib import Path\nrepo_root = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()\nprint('Repo root:', repo_root)\n
