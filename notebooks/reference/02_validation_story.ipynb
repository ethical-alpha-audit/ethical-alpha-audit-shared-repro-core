# %% [markdown]
# # Validation contract — reference narrative
#
# **Layer A.** **No code.**
#
# Summarises **`config/expected_outputs.json`** (pinned paths + SHA-256). Does **not** run the harness.
#
# **How to use:** Read the contract statically; use **`02_validation_execute.ipynb`** for a Python echo.
#
# ## Scientific integrity
#
# Pins are enforced by **`reproduce_all.py`** after a clean run.
