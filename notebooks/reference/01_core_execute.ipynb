# %% [markdown]
# # Technical — core API echo
#
# **Layer B.** Calls `reference_notebook_helpers.run_core_reference_demo`.

# %%
from reference_notebook_helpers import run_core_reference_demo

run_core_reference_demo()

# %% [markdown]
# ## Note
#
# Does **not** write hash-locked CSV/summary; see archival execute notebooks.
