# %% [markdown]
# # Core engine API — reference narrative
#
# **Layer A — technical reference, secondary.** **No code.**
#
# **Purpose:** Orient readers to the **`evaluate_case`** replay smoke vector and digest—without writing `outputs/`.
#
# **How to use:** Read statically; for a live echo, open **`01_core_execute.ipynb`** or run **`python reproduce_all.py`** for contract artefacts.
#
# ## Interpretation
#
# Same **smoke_core_001** features as archival step 1; this path is **display / education** only.
#
# ## Scientific integrity
#
# Not part of `notebook_plan.json`.
