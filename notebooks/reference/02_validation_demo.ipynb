# %% [markdown]
# # Validation contract overview (technical reference)
#
# **Suite role:** **Reference-only / technical** — **not** in the archival plan.
#
# **Purpose:** Read the output manifest contract **without** running the full harness.
#
# **How to use:** Static table below lists pinned artefacts. Run the appendix to echo the same from Python if desired.

# %% [markdown]
# ## Static contract snapshot (precomputed)
#
# | path | required | sha256 (pinned) |
# | --- | --- | --- |
# | outputs/tables/smoke_test_results.csv | true | `d967a43d2b635ca923a7c2d0c60c523c1bf0c655b18bed442e6f686d7d190ce0` |
# | outputs/figures/smoke_test_summary.txt | true | `dbf23caa21c0f35a00ae80ce4db2147bc4cdf95c8df7965f6af6d720de0294c6` |
# | outputs/tables/utilities_validation.csv | true | `7e0ed8a73eaad12fb02c21b25e9493512be237312dbec159ed67f01080e3124f` |
# | outputs/figures/demo_pipeline_summary.txt | true | `8951ee203a83dfab8368afaf1b5b295372ee24491ee95c4e3af046cfc022cc48` |

# %% [markdown]
# ## Interpretation
#
# These digests are what **`reproduce_all.py`** enforces after a clean run. Editing files without updating pins breaks validation.
#
# ## Scientific integrity note
#
# This overview **does not** replace **`python reproduce_all.py`**.

# %% [markdown]
# ---
#
# ## Technical appendix — live echo
#
# Calls `reference_notebook_helpers.run_validation_overview_demo()`.

# %%
from reference_notebook_helpers import run_validation_overview_demo

run_validation_overview_demo()
