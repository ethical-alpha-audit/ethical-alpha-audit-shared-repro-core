# %% [markdown]
# # Core engine API (technical reference)
#
# **Suite role:** **Reference-only / technical** — **not** in `config/notebook_plan.json`; **non-canonical**; **does not** write `outputs/`.
#
# **Purpose:** Minimal text snapshot of **`evaluate_case`** on the **smoke_core_001** feature vector in **replay mode**.
#
# **How to use:** Read the static block below. Run the appendix only if you want to re-print from a live kernel.

# %% [markdown]
# ## Static reference output (precomputed)
#
# ```
# Technical reference — core API (display only; no writes under outputs/)
#   case_id:               smoke_core_001
#   governance_outcome:    APPROVE
#   all_gates_pass:        1
#   compensatory_score:    0.5535
#   compensatory_approved: 1
#   approved:              1
#   result_sha256:         4c797545771b95ddfefb32e810a58d0431de8d6eb6317b096f0f0a7fc2c84584
#
# For hash-locked CSV/summary artefacts, run notebooks/archival_shared/01_smoke_test.ipynb via reproduce_all.py.
# ```

# %% [markdown]
# ## Interpretation
#
# Same case vector as archival smoke; this notebook **does not** emit contract files.
#
# ## Scientific integrity note
#
# Reference notebooks are **reading aids**; validation remains archival + `expected_outputs.json`.

# %% [markdown]
# ---
#
# ## Technical appendix — live print
#
# Calls `reference_notebook_helpers.run_core_reference_demo()`.

# %%
from reference_notebook_helpers import run_core_reference_demo

run_core_reference_demo()
