# %% [markdown]
# # Example notebook
#
# Minimal reader-first placeholder under `notebooks/`. Not listed in `config/notebook_plan.json`; present so `*.ipynb` corpus checks see valid nbformat JSON.

# %%
# Safe no-op if run manually
pass
