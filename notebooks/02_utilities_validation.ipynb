# %% [markdown]
# # 02_utilities_validation.ipynb
# Deterministic placeholder notebook.

# %%
from pathlib import Path
import csv

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
for rel in [
    'outputs/tables/utilities_validation.csv',
]:
    p = ROOT / rel
    p.parent.mkdir(parents=True, exist_ok=True)
    if p.suffix == '.csv':
        with open(p, 'w', newline='', encoding='utf-8') as f:
            writer = csv.writer(f)
            writer.writerow(['artifact', 'source_notebook'])
            writer.writerow([p.name, '02_utilities_validation.ipynb'])
    else:
        p.write_text(f'deterministic artifact generated by {p.name}\n', encoding='utf-8')
print('Deterministic placeholder outputs generated')
