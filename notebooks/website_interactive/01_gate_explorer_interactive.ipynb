# %% [markdown]
# > **Academic viewing:** In **Voila** or **Binder’s Voila URL** (`/voila/render/...`), input cells are not shown to readers—only narrative and live controls. In classic Jupyter, an implementation cell appears below; it calls shared helpers and does not reimplement engine logic.
#
#
# # Gate & verdict explorer — interactive instrument (website layer)
#
# **Non-canonical.** **Display-only.**
#
# ## How to use
#
# **Restart & Run All.** Choose **Scenario**, **Profile**; toggle detail panels.
#
# ## Interactive experiment surface

# %%
from ui_gate_explorer import launch_gate_explorer_ui

launch_gate_explorer_ui()

# %% [markdown]
# ## Interpretation & integrity
#
# Bars: gate pass/fail. Verdict table: headline fields from **`evaluate_case`**. **No writes** to `outputs/`.
