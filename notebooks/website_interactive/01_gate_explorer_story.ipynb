# %% [markdown]
# # Interactive gate exploration — narrative (website layer)
#
# **Non-canonical.** **No code** in this file.
#
# **Purpose:** Describe the **primary polished demonstrator**: scenario × profile × **gate bars** × **verdict** × **SCM/abstention** toggles—bounded, engine-backed, **display-only** (no `outputs/` writes).
#
# **Full experiment story:** Readers see how **non-compensatory gates**, **explicit activation thresholds**, and **structured override governance** under **replay vs full** modes produce **deterministic** readable outcomes; **structured abstention / fallback** fields appear only in **full**-mode scenarios.
#
# **How to use:** Open **`01_gate_explorer_interactive.ipynb`** (prefer Voila for code-free UI). **Restart & Run All** in Jupyter if needed.
#
# ## Interpretation
#
# Tightening **Profile** can flip gates without changing frozen feature inputs. **Exploration** never alters canonical artefacts.
#
# ## Scientific integrity
#
# Presentation layer only; engine module and pins unchanged.
