# %% [markdown]
# # NON-CANONICAL WEBSITE INTERACTIVE NOTEBOOK
#
# ## Website-facing layer (not part of archival validation)
#
# This folder is **deliberately excluded** from `config/notebook_plan.json` and `config/expected_outputs.json`. Nothing here replaces archival notebooks; it is a reader-first exploration layer for governance academics.
#
# ### How to use
#
# Run all cells, then use the visible controls. You do not need to edit code.
#
# ### Dependencies
#
# This repository includes ipywidgets for bounded interactive exploration in Jupyter and Binder environments.
#
# ### Scientific integrity note
#
# Interactive controls here are presentation-layer only: they call the same authoritative engine pathways as archival notebooks and do not write canonical outputs. The underlying system is an auditable decision framework with non-compensatory gates, explicit activation thresholds, and structured override governance, producing deterministic inspectable outcomes.
