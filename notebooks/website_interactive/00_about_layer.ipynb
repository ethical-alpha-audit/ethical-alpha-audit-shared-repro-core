# %% [markdown]
# # NON-CANONICAL WEBSITE INTERACTIVE NOTEBOOK
#
# ## Website-facing layer (not part of archival validation)
#
# This folder is **deliberately excluded** from `config/notebook_plan.json` and `config/expected_outputs.json`. Nothing here may replace the archival notebooks under `notebooks/archival_shared/`.
#
# ### Dependencies
#
# This repository includes ipywidgets for bounded interactive exploration in Jupyter and Binder environments.
#
# ### What you get
#
# The companion notebooks provide a bounded interactive interface using controls (dropdowns, checkboxes, and fixed scenario/profile options) that call the same authoritative engine pathways used in archival notebooks. This layer is display-only and does not write canonical outputs.
