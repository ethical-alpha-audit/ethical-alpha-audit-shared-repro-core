# %% [markdown]
# # Notebook suite orientation (website layer)
#
# **Suite role:** **Non-canonical / reader-facing interactive** — excluded from `config/notebook_plan.json` and `config/expected_outputs.json`.
#
# **Purpose:** Map **canonical** archival artefacts versus **optional** demonstrations.
#
# **Static reading:** Each notebook in this folder begins with **markdown exhibits** you can read on GitHub or nbviewer **without a kernel**.
#
# **Execution:** Open in Jupyter or Binder and run the **Technical appendix** when you want **live ipywidgets** or to confirm engine behaviour interactively.
#
# ## Suite map
#
# | Location | Canonical? | Writes `outputs/`? |
# | --- | --- | --- |
# | `notebooks/archival_shared/` | **Yes** | **Yes** (declared only) |
# | `notebooks/website_interactive/` | **No** | **No** |
# | `notebooks/reference/` | **No** | **No** |
#
# ## Scientific integrity note
#
# Website demos call the same **public API** as archival code paths but **never replace** manifest validation. Binding records come from **`python reproduce_all.py`** and `config/expected_outputs.json`.
